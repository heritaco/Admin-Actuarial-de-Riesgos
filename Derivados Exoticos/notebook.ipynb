# %%
import Merton_Riesgo_Default as mrd

# %%
params =  {
        "E_target": 2_360_000_000.0,
        "Sigma_E": 0.3089,
        "D": 101_604_000.0,
        "T": 1.0,
        "R": 0.0542,
        "pd_floor": 0.03,
    }

V0_imp, sigmaV_imp, sol_info = mrd.solve_merton(params)

# Si no convergió, aún podemos mostrar el último intento, pero marcando el fallo.
outputs = mrd.compute_outputs(V0_imp, sigmaV_imp, params)

mrd.print_report(sol_info, outputs)
# Out:
# === Solver info ===
# Converged: True
# Message: The solution converged.
# nfev: 7
# Initial guess used: [1.9692832e+09 5.0000000e-02]
#
# === Calibrated parameters ===
# V0 (implied): 2456243641.0957885
# sigma_V (implied): 0.28170558958564895
#
# === d1, d2 and normals ===
# d1: 11.640466938282495
# d2: 11.358761348696847
# N(d1): 100.0 %
# N(d2): 100.0 %
#
# === Default probability (risk-neutral) ===
# PD_rn = N(-d2): 3.3544549054251953e-28 %
# PD_used (with floor if any): 3.0 %
#
# === Fit checks (should match targets) ===
# E_model: 2360000000.0
# E_target: 2360000000.0
# SigmaE_model: 0.2931938826613942
# Sigma_E target: 0.3089
